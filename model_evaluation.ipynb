# %%
from uav import UAVModel
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Evaluating DJI Inspire

# %%
# Validation with DJI Inspire
dji = UAVModel()
dji.setAll(temp=25, h=10, mass=28.73 / 9.81, nr=4, Dp=13, Hp=4.5, Bp=2, Kv0=350, Um0=10, Im0=0.3,
            Rm=0.21, Re=0.02, Ub=24, Cb=5700, Cmin=5000 * 0.15, Rb=0.12, Icontrol=1, safe_duty_cycle=0.9)
dji.calculate_performance()
dji.show_all()
# Out:
# ----------------------------------------
#         UAV Model Configuration
# ----------------------------------------
# ----------------------------------------
#             Input parameters
# ----------------------------------------
#               Environment
# Temperature:                      25.000 °C
# Altitude:                         10.000 m
#
#                 General
# Mass:                              2.929 Kg
#
#                Propeller
# Diameter:                          0.330 m
# Pitch:                             0.114 m
# Blade number:                      2.000 units
#
#                  Motor
# Motor constant:                  350.000 rpm/V
# Motor no-load voltage:            10.000 V
# Motor no-load current:             0.300 A
# Motor resistance:                  0.210 Ohm
# Number of rotors:                  4.000 units
#
#                   ESC
# Equivalent resistance:             0.020 Ohm
#
#                 Battery
# ...

# %% [markdown]
# ## Evaluating Alta X FreeFly

# %%
alta_x = UAVModel()

alta_x.setAll(
    temp=20,
    h=60,
    mass=10.4,
    Dp=33,
    Hp=9,
    Bp=2,
    Kv0=115,
    Um0=10,
    Im0=1.18,
    Rm=0.01,
    nr=4,
    Re=0.001,
    Ub=44.4,
    Cb=2*16000,
    Cmin=1600,
    Rb=0.2,
    Icontrol=1.0,
    safe_duty_cycle=0.9,
)

alta_x.calculate_performance()
alta_x.show_all()
# Out:
# ----------------------------------------
#         UAV Model Configuration
# ----------------------------------------
# ----------------------------------------
#             Input parameters
# ----------------------------------------
#               Environment
# Temperature:                      20.000 °C
# Altitude:                         60.000 m
#
#                 General
# Mass:                             10.400 Kg
#
#                Propeller
# Diameter:                          0.838 m
# Pitch:                             0.229 m
# Blade number:                      2.000 units
#
#                  Motor
# Motor constant:                  115.000 rpm/V
# Motor no-load voltage:            10.000 V
# Motor no-load current:             1.180 A
# Motor resistance:                  0.010 Ohm
# Number of rotors:                  4.000 units
#
#                   ESC
# Equivalent resistance:             0.001 Ohm
#
#                 Battery
# ...
